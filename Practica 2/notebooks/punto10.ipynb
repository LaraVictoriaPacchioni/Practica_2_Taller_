# %%
import sys
sys.path.append("../src")

# %%
from ejercicio_10 import run_competition

# %%
run_competition()
# Out:
# Ronda 1 - Entrada:
# Ganador/a: Camila (26 pts)
#
# Tabla de posiciones:
# Cocinero       Puntaje    Rondas ganadas    Mejor ronda    Promedio
# -------------------------------------------------------------------
# Camila              26                 1             26        26.0
# Valentina           24                 0             24        24.0
# Lucía               24                 0             24        24.0
# Mateo               22                 0             22        22.0
# Santiago            19                 0             19        19.0
#
#
# Ronda 2 - Plato principal:
# Ganador/a: Valentina (26 pts)
#
# Tabla de posiciones:
# Cocinero       Puntaje    Rondas ganadas    Mejor ronda    Promedio
# -------------------------------------------------------------------
# Valentina           50                 1             26        25.0
# Mateo               46                 0             24        23.0
# ...
